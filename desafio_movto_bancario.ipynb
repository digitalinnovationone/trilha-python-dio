# %% [markdown]
# <a href="https://colab.research.google.com/github/Murillo10/trilha-python-dio/blob/main/desafio_movto_bancario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu = """
Olá Cliente!
É um prazer vê-lo novamente.
Por favor, escolha uma das opções no menu abaixo:

[d] Depositar
[e] Extrato
[s] Sacar
[t] Transferir
[x] Sair

=> """

saldo = 0
limite_1 = 500
limite_2 = 1000
extrato = ""
numero_saques = 0
numero_transferencias = 0
LIMITE_SAQUES = 3
LIMITE_TRANSFERENCIAS = 5

while True:

    opcao = input(menu)

    if opcao == "d":
        valor = float(input("Informe o valor do depósito: "))

        if valor > 0:
            saldo += valor
            extrato += f"Depósito: R$ {valor:.2f}\n"

        else:
            print("Operação falhou! O valor informado é inválido.")

    elif opcao == "s":
        valor = float(input("Informe o valor do saque: "))

        excedeu_saldo = valor > saldo

        excedeu_limite = valor > limite_1

        excedeu_saques = numero_saques >= LIMITE_SAQUES

        if excedeu_saldo:
            print("Operação falhou! Você não tem saldo suficiente.")

        elif excedeu_limite:
            print("Operação falhou! O valor do saque excede o limite.")

        elif excedeu_saques:
            print("Operação falhou! Número máximo de saques excedido.")

        elif valor > 0:
            saldo -= valor
            extrato += f"Saque: R$ {valor:.2f}\n"
            numero_saques += 1

    elif opcao == "t":
        valor = float(input("Informe o valor da transferencia: "))

        excedeu_saldo = valor > saldo

        excedeu_limite = valor > limite_2

        excedeu_saques = numero_saques >= LIMITE_SAQUES

        if excedeu_saldo:
            print("Operação falhou! Você não tem saldo suficiente.")

        elif excedeu_limite:
            print("Operação falhou! O valor da transferencia excede o limite.")

        elif excedeu_saques:
            print("Operação falhou! Número máximo de transferencias foi excedido.")

        elif valor > 0:
            saldo -= valor
            extrato += f"Transferir: R$ {valor:.2f}\n"
            numero_transferencias += 1
        else:
            print("Operação falhou! O valor informado é inválido.")

    elif opcao == "e":
        print("\n================ EXTRATO DE MOVIMENTAÇÃO ================")
        print("Não foram realizadas movimentações." if not extrato else extrato)
        print(f"\nSaldo: R$ {saldo:.2f}")
        print("==========================================")

    elif opcao == "x":
        print("Tchau...Volte Sempre!")
        break

    else:
        print("Operação inválida, por favor selecione novamente a operação desejada.")
# Out:
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => d
# Informe o valor do depósito: 5000
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => s
# Informe o valor do saque: 600
# Operação falhou! O valor do saque excede o limite.
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => s
# Informe o valor do saque: 500
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => e
#
# ================ EXTRATO DE MOVIMENTAÇÃO ================
# Depósito: R$ 5000.00
# Saque: R$ 500.00
#
#
# Saldo: R$ 4500.00
# ==========================================
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => t
# Informe o valor da transferencia: 600
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => e
#
# ================ EXTRATO DE MOVIMENTAÇÃO ================
# Depósito: R$ 5000.00
# Saque: R$ 500.00
# Transferir: R$ 600.00
#
#
# Saldo: R$ 3900.00
# ==========================================
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => t
# Informe o valor da transferencia: 500
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => e
#
# ================ EXTRATO DE MOVIMENTAÇÃO ================
# Depósito: R$ 5000.00
# Saque: R$ 500.00
# Transferir: R$ 600.00
# Transferir: R$ 500.00
#
#
# Saldo: R$ 3400.00
# ==========================================
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => t
# Informe o valor da transferencia: 2000
# Operação falhou! O valor da transferencia excede o limite.
#
# Olá Cliente!
# É um prazer vê-lo novamente.
# Por favor, escolha uma das opções no menu abaixo:
#
# [d] Depositar
# [e] Extrato
# [s] Sacar
# [t] Transferir
# [x] Sair
#
# => x
# Tchau...Volte Sempre!
